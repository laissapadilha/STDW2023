# %% [markdown]
# <a href="https://colab.research.google.com/github/laissapadilha/STDW2023/blob/main/Desafio_ETL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Considerando um base de clientes fictícia, serão criadas mensagens personalizadas a serem enviadas via e-mail, com base nos seguintes critérios:
#
#
# *   Clientes com saldo devedor em conta;
# *   Clientes com saldo disponível em conta superior a R$ 1.000,00 e que poderiam realizar algum investimento;
#
# *   Clientes com limite disponível no cartão de crédito abaixo de R$ 1.000,00, que não possuem saldo devedor em conta e nem atraso no cartão, e que portanto poderiam ter algum aumento de limite;
# *   Clientes com atraso de pagamento no cartão de crédito.

# %% [markdown]
# ## **Extract**

# %%
# Importando Pandas
import pandas as pd
# Importando base de clientes
base = pd.read_excel('base_clientes.xlsx')

# %%
# Visualizando primeiras linhas da base
base.head()
# Out:
#              Nome  Agencia  Conta                      e-mail  Saldo_Conta  \
# 0  Joao Rodrigues       11  74220    Joao_Rodrigues@gmail.com         7495
# 1    Jose Andrade       19  80967      Jose_Andrade@yahoo.com        -1141
# 2  Maria Ferreira       11  71619  Maria_Ferreira@hotmail.com         6152
# 3  Davi Gonçalves       25  82105  Davi_Gonçalves@hotmail.com         2168
# 4      Joao Mello       11  84619      Joao_Mello@hotmail.com         3636
#
#    Limite_Conta  Dias_Uso_Limite_Conta  Saldo_Cartao  Limite_Cartao  \
# 0          9500                      0          5025          17250
# 1          4100                     71          3685          13500
# 2          1700                      0          1023           6750
# 3          5800                      0           933           6250
# 4           700                      0          1520           8500
#
#    Limite_Disponível_Cartão  Dias_Atraso_Cartao
# 0                     12225                   0
# 1                      9815                   0
# 2                      5727                   0
# 3                      5317                   0
# 4                      6980                   0

# %%
# Verificando informações gerais da base e se há valores nulos
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Nome                      95 non-null     object
#  1   Agencia                   95 non-null     int64
#  2   Conta                     95 non-null     int64
#  3   e-mail                    95 non-null     object
#  4   Saldo_Conta               95 non-null     int64
#  5   Limite_Conta              95 non-null     int64
#  6   Dias_Uso_Limite_Conta     95 non-null     int64
#  7   Saldo_Cartao              95 non-null     int64
#  8   Limite_Cartao             95 non-null     int64
#  9   Limite_Disponível_Cartão  95 non-null     int64
#  10  Dias_Atraso_Cartao        95 non-null     int64
# dtypes: int64(9), object(2)
# memory usage: 8.3+ KB

# %%
# Criando função para consultar cliente pelo nome
cliente = base.Nome.tolist()
def get_cliente(cliente):
  return base.loc[base.Nome == cliente]

# %%
# Testando a função
get_cliente('Jose Andrade')
# Out:
#            Nome  Agencia  Conta                  e-mail  Saldo_Conta  \
# 1  Jose Andrade       19  80967  Jose_Andrade@yahoo.com        -1141
#
#    Limite_Conta  Dias_Uso_Limite_Conta  Saldo_Cartao  Limite_Cartao  \
# 1          4100                     71          3685          13500
#
#    Limite_Disponível_Cartão  Dias_Atraso_Cartao
# 1                      9815                   0

# %% [markdown]
# ## **Transform**

# %%
# Criando mensagens persolinazadas para clientes com saldo devedor em conta / que estão utilizando o cheque especial, sugerindo a contratação de um empréstimo
devedores_conta = base.loc[base.Saldo_Conta <0]
for index, cliente in devedores_conta.iterrows():
    print(f"Olá, {cliente['Nome']}!\n\nAgência {cliente['Agencia']} Conta {cliente['Conta']}\n\nVerificamos que há {cliente['Dias_Uso_Limite_Conta']} dias você está usando o limite do cheque especial da sua conta.\nVamos contratar um empréstimo e reduzir a taxa de juros que você está pagando? \n\nContate seu gerente de contas para obter opções mais vantajosas.\n------------------------------------------------------------------------------------------")
# Out:
# Olá, Jose Andrade!
#
# Agência 19 Conta 80967
#
# Verificamos que há 71 dias você está usando o limite do cheque especial da sua conta.
# Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Bernardo Rodrigues!
#
# Agência 10 Conta 69897
#
# Verificamos que há 80 dias você está usando o limite do cheque especial da sua conta.
# Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Heitor Almeida!
#
# Agência 7 Conta 65058
#
# Verificamos que há 19 dias você está usando o limite do cheque especial da sua conta.
# Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Miguel Mello!
#
# Agência 2 Conta 58144
#
# Verificamos que há 39 dias você está usando o limite do cheque especial da sua conta.
# Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Ana Almeida!
#
# Agência 3 Conta 52051
#
# Verificamos que há 11 dias você está usando o limite do cheque especial da sua conta.
# Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Gabriel Santos!
#
# Agência 6 Conta 72089
#
# Verificamos que há 10 dias você está usando o limite do cheque especial da sua conta.
# Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Maria Martins!
#
# Agência 6 Conta 84777
#
# Verificamos que há 101 dias você está usando o limite do cheque especial da sua conta.
# Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Lorenzo Pereira!
#
# Agência 5 Conta 51648
#
# Verificamos que há 25 dias você está usando o limite do cheque especial da sua conta.
# Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Lorenzo Santos!
#
# Agência 12 Conta 89706
#
# Verificamos que há 90 dias você está usando o limite do cheque especial da sua conta.
# Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Eduarda Torres!
#
# Agência 18 Conta 97126
#
# Verificamos que há 109 dias você está usando o limite do cheque especial da sua conta.
# Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Bernardo Fernandes!
#
# Agência 14 Conta 55267
#
# Verificamos que há 7 dias você está usando o limite do cheque especial da sua conta.
# Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Gabriel Vieira!
#
# Agência 19 Conta 66240
#
# Verificamos que há 120 dias você está usando o limite do cheque especial da sua conta.
# Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Vander Almeida!
#
# Agência 19 Conta 79975
#
# Verificamos que há 108 dias você está usando o limite do cheque especial da sua conta.
# Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Eduarda Barbosa!
#
# Agência 12 Conta 60337
#
# Verificamos que há 101 dias você está usando o limite do cheque especial da sua conta.
# Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Gabriel Torres!
#
# Agência 8 Conta 62813
#
# Verificamos que há 107 dias você está usando o limite do cheque especial da sua conta.
# Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Joana Pinto!
#
# Agência 15 Conta 98878
#
# Verificamos que há 86 dias você está usando o limite do cheque especial da sua conta.
# Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Carlos Araújo!
#
# Agência 7 Conta 85382
#
# Verificamos que há 102 dias você está usando o limite do cheque especial da sua conta.
# Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Enzo Carvalho!
#
# Agência 25 Conta 61679
#
# Verificamos que há 36 dias você está usando o limite do cheque especial da sua conta.
# Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Miguel Pinto!
#
# Agência 19 Conta 68371
#
# Verificamos que há 41 dias você está usando o limite do cheque especial da sua conta.
# Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Ana Martins!
#
# Agência 20 Conta 93913
#
# Verificamos que há 120 dias você está usando o limite do cheque especial da sua conta.
# Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Gabriel Martins!
#
# Agência 10 Conta 86672
#
# Verificamos que há 18 dias você está usando o limite do cheque especial da sua conta.
# Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Jose Martins!
#
# Agência 21 Conta 96225
#
# Verificamos que há 69 dias você está usando o limite do cheque especial da sua conta.
# Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Enzo Fernandes!
#
# Agência 8 Conta 94420
#
# Verificamos que há 106 dias você está usando o limite do cheque especial da sua conta.
# Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------

# %%
# Criando mensagens persolinazadas para clientes com saldo disponível em conta maior do que R$ 1.000,00 (possíveis investidores)
saldo_positivo = base.loc[base.Saldo_Conta >1000]
for index, cliente in saldo_positivo.iterrows():
    print(f"Olá, {cliente['Nome']}!\n\nAgência {cliente['Agencia']} Conta {cliente['Conta']}\n\nVerificamos que você possui R$ {cliente['Saldo_Conta']:.2f} disponível em sua conta corrente.\nVamos investir e fazer o seu dinheiro render mais? \n\nContate seu gerente de contas para obter opções mais vantajosas.\n------------------------------------------------------------------------------------------")
# Out:
# Olá, Joao Rodrigues!
#
# Agência 11 Conta 74220
#
# Verificamos que você possui R$ 7495.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Maria Ferreira!
#
# Agência 11 Conta 71619
#
# Verificamos que você possui R$ 6152.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Davi Gonçalves!
#
# Agência 25 Conta 82105
#
# Verificamos que você possui R$ 2168.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Joao Mello!
#
# Agência 11 Conta 84619
#
# Verificamos que você possui R$ 3636.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Pedro Costa!
#
# Agência 11 Conta 87146
#
# Verificamos que você possui R$ 4824.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Vander Alves!
#
# Agência 3 Conta 57645
#
# Verificamos que você possui R$ 4163.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Gabriel Mello!
#
# Agência 6 Conta 93051
#
# Verificamos que você possui R$ 6807.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Heitor Martins!
#
# Agência 13 Conta 99658
#
# Verificamos que você possui R$ 1083.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Théo Gonçalves!
#
# Agência 16 Conta 87607
#
# Verificamos que você possui R$ 3794.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Gabriel Costa!
#
# Agência 8 Conta 57858
#
# Verificamos que você possui R$ 3008.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Enzo Cardoso!
#
# Agência 13 Conta 96745
#
# Verificamos que você possui R$ 7744.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Enzo Ribeiro!
#
# Agência 12 Conta 77986
#
# Verificamos que você possui R$ 3469.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Joana Torres!
#
# Agência 13 Conta 88012
#
# Verificamos que você possui R$ 8937.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Eduardo Martins!
#
# Agência 3 Conta 71539
#
# Verificamos que você possui R$ 2581.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Vander Ferreira!
#
# Agência 18 Conta 64572
#
# Verificamos que você possui R$ 1059.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Katia Lima!
#
# Agência 18 Conta 62351
#
# Verificamos que você possui R$ 5971.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Vander Ramos!
#
# Agência 13 Conta 79962
#
# Verificamos que você possui R$ 7979.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Bernardo Araújo!
#
# Agência 3 Conta 56470
#
# Verificamos que você possui R$ 3439.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Eduarda Ramos!
#
# Agência 22 Conta 62052
#
# Verificamos que você possui R$ 7301.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Miguel Vieira!
#
# Agência 13 Conta 56734
#
# Verificamos que você possui R$ 8792.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Enzo Alves!
#
# Agência 2 Conta 55372
#
# Verificamos que você possui R$ 9755.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Eduardo Ramos!
#
# Agência 22 Conta 55847
#
# Verificamos que você possui R$ 1252.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Bernardo Vieira!
#
# Agência 17 Conta 64104
#
# Verificamos que você possui R$ 5509.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Pedro Fernandes!
#
# Agência 24 Conta 54720
#
# Verificamos que você possui R$ 7920.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Jose Rodrigues!
#
# Agência 9 Conta 69223
#
# Verificamos que você possui R$ 4166.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Lorenzo Barbosa!
#
# Agência 25 Conta 84090
#
# Verificamos que você possui R$ 2762.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Théo Torres!
#
# Agência 5 Conta 70783
#
# Verificamos que você possui R$ 5773.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Pedro Santos!
#
# Agência 24 Conta 53413
#
# Verificamos que você possui R$ 9333.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Lorenzo Gonçalves!
#
# Agência 11 Conta 73346
#
# Verificamos que você possui R$ 7758.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Eduarda Oliveira!
#
# Agência 8 Conta 85887
#
# Verificamos que você possui R$ 5908.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Vander Cardoso!
#
# Agência 12 Conta 63705
#
# Verificamos que você possui R$ 1461.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Joana Mello!
#
# Agência 22 Conta 77496
#
# Verificamos que você possui R$ 2903.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Eduardo Souza!
#
# Agência 10 Conta 78242
#
# Verificamos que você possui R$ 3817.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Ana Pinto!
#
# Agência 10 Conta 71141
#
# Verificamos que você possui R$ 1346.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Katia Alves!
#
# Agência 20 Conta 67231
#
# Verificamos que você possui R$ 1426.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Gabriel Cardoso!
#
# Agência 15 Conta 94423
#
# Verificamos que você possui R$ 8421.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Miguel Araújo!
#
# Agência 8 Conta 77635
#
# Verificamos que você possui R$ 5276.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Maria Souza!
#
# Agência 18 Conta 56571
#
# Verificamos que você possui R$ 4872.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Théo Fernandes!
#
# Agência 19 Conta 75730
#
# Verificamos que você possui R$ 9575.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Maria Silva!
#
# Agência 19 Conta 76393
#
# Verificamos que você possui R$ 8813.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Pedro Mello!
#
# Agência 1 Conta 87346
#
# Verificamos que você possui R$ 5269.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Gabriel Ramos!
#
# Agência 10 Conta 71872
#
# Verificamos que você possui R$ 5302.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Théo Rodrigues!
#
# Agência 23 Conta 80381
#
# Verificamos que você possui R$ 8866.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Jose Gonçalves!
#
# Agência 22 Conta 60414
#
# Verificamos que você possui R$ 4315.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Katia Almeida!
#
# Agência 15 Conta 88976
#
# Verificamos que você possui R$ 8892.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Enzo Gomes!
#
# Agência 17 Conta 56068
#
# Verificamos que você possui R$ 2833.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Miguel Oliveira!
#
# Agência 24 Conta 51358
#
# Verificamos que você possui R$ 1407.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Pedro Ribeiro!
#
# Agência 14 Conta 68882
#
# Verificamos que você possui R$ 5084.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Ana Ferreira!
#
# Agência 3 Conta 63793
#
# Verificamos que você possui R$ 2950.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Eduardo Carvalho!
#
# Agência 21 Conta 79829
#
# Verificamos que você possui R$ 8454.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Enzo Oliveira!
#
# Agência 4 Conta 54086
#
# Verificamos que você possui R$ 8385.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Ana Oliveira!
#
# Agência 2 Conta 76642
#
# Verificamos que você possui R$ 3428.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Joao Lima!
#
# Agência 24 Conta 85424
#
# Verificamos que você possui R$ 5308.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Miguel Carvalho!
#
# Agência 15 Conta 59423
#
# Verificamos que você possui R$ 9352.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Jose Carvalho!
#
# Agência 18 Conta 66784
#
# Verificamos que você possui R$ 4907.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Théo Alves!
#
# Agência 9 Conta 99361
#
# Verificamos que você possui R$ 2973.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Lorenzo Oliveira!
#
# Agência 5 Conta 59365
#
# Verificamos que você possui R$ 4541.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Maria Torres!
#
# Agência 19 Conta 80611
#
# Verificamos que você possui R$ 5798.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Gabriel Fernandes!
#
# Agência 2 Conta 86221
#
# Verificamos que você possui R$ 3918.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Heitor Costa!
#
# Agência 15 Conta 55313
#
# Verificamos que você possui R$ 8824.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Carlos Vieira!
#
# Agência 18 Conta 93313
#
# Verificamos que você possui R$ 5672.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Miguel Santos!
#
# Agência 2 Conta 94154
#
# Verificamos que você possui R$ 4143.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Jose Cardoso!
#
# Agência 5 Conta 82071
#
# Verificamos que você possui R$ 8806.00 disponível em sua conta corrente.
# Vamos investir e fazer o seu dinheiro render mais?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------

# %%
# Criando mensagens persolinazadas para clientes com saldo disponível abaixo de R$ 1.000,00, que não estão usando o limite da conta e nem estão em atraso no cartão, sugerindo aumento de limite
limite_cartao = base.loc[(base.Limite_Disponível_Cartão <1000) & 	(base.Dias_Uso_Limite_Conta == 0) & (base.Dias_Atraso_Cartao == 0)]
for index, cliente in limite_cartao.iterrows():
    print(f"Olá, {cliente['Nome']}!\n\nAgência {cliente['Agencia']} Conta {cliente['Conta']}\n\nVerificamos que você possui apenas R$ {cliente['Limite_Disponível_Cartão']:.2f} de limite disponível em seu cartão de crédito.\nVamos aumentar seu limite para que você possa aproveitar ainda mais os benefícios do nosso cartão? \n\nContate seu gerente de contas para obter opções mais vantajosas.\n------------------------------------------------------------------------------------------")
# Out:
# Olá, Pedro Santos!
#
# Agência 24 Conta 53413
#
# Verificamos que você possui apenas R$ 971.00 de limite disponível em seu cartão de crédito.
# Vamos aumentar seu limite para que você possa aproveitar ainda mais os benefícios do nosso cartão?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Maria Fernandes!
#
# Agência 8 Conta 67572
#
# Verificamos que você possui apenas R$ 682.00 de limite disponível em seu cartão de crédito.
# Vamos aumentar seu limite para que você possa aproveitar ainda mais os benefícios do nosso cartão?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Ana Ferreira!
#
# Agência 3 Conta 63793
#
# Verificamos que você possui apenas R$ 557.00 de limite disponível em seu cartão de crédito.
# Vamos aumentar seu limite para que você possa aproveitar ainda mais os benefícios do nosso cartão?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Théo Alves!
#
# Agência 9 Conta 99361
#
# Verificamos que você possui apenas R$ 955.00 de limite disponível em seu cartão de crédito.
# Vamos aumentar seu limite para que você possa aproveitar ainda mais os benefícios do nosso cartão?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------

# %%
# Criando mensagens persolinazadas para clientes com atraso no cartão de crédito, sugerindo parcelamento de fatura
devedores_cartao = base.loc[base.Dias_Atraso_Cartao >0]
for index, cliente in devedores_cartao.iterrows():
    print(f"Olá, {cliente['Nome']}!\n\nAgência {cliente['Agencia']} Conta {cliente['Conta']}\n\nVerificamos que sua fatura do cartão de crédito está em atraso há {cliente['Dias_Atraso_Cartao']} dias.\nVamos contratar um parcelamento de fatura e reduzir a taxa de juros que você está pagando? \n\nContate seu gerente de contas para obter opções mais vantajosas.\n------------------------------------------------------------------------------------------")
# Out:
# Olá, Théo Gonçalves!
#
# Agência 16 Conta 87607
#
# Verificamos que sua fatura do cartão de crédito está em atraso há 113 dias.
# Vamos contratar um parcelamento de fatura e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Enzo Cardoso!
#
# Agência 13 Conta 96745
#
# Verificamos que sua fatura do cartão de crédito está em atraso há 102 dias.
# Vamos contratar um parcelamento de fatura e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Pedro Fernandes!
#
# Agência 24 Conta 54720
#
# Verificamos que sua fatura do cartão de crédito está em atraso há 81 dias.
# Vamos contratar um parcelamento de fatura e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Eduardo Ferreira!
#
# Agência 19 Conta 74599
#
# Verificamos que sua fatura do cartão de crédito está em atraso há 86 dias.
# Vamos contratar um parcelamento de fatura e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Théo Torres!
#
# Agência 5 Conta 70783
#
# Verificamos que sua fatura do cartão de crédito está em atraso há 105 dias.
# Vamos contratar um parcelamento de fatura e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Katia Almeida!
#
# Agência 15 Conta 88976
#
# Verificamos que sua fatura do cartão de crédito está em atraso há 112 dias.
# Vamos contratar um parcelamento de fatura e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Enzo Oliveira!
#
# Agência 4 Conta 54086
#
# Verificamos que sua fatura do cartão de crédito está em atraso há 75 dias.
# Vamos contratar um parcelamento de fatura e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Maria Torres!
#
# Agência 19 Conta 80611
#
# Verificamos que sua fatura do cartão de crédito está em atraso há 81 dias.
# Vamos contratar um parcelamento de fatura e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Heitor Costa!
#
# Agência 15 Conta 55313
#
# Verificamos que sua fatura do cartão de crédito está em atraso há 62 dias.
# Vamos contratar um parcelamento de fatura e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------
# Olá, Ana Santos!
#
# Agência 18 Conta 61152
#
# Verificamos que sua fatura do cartão de crédito está em atraso há 31 dias.
# Vamos contratar um parcelamento de fatura e reduzir a taxa de juros que você está pagando?
#
# Contate seu gerente de contas para obter opções mais vantajosas.
# ------------------------------------------------------------------------------------------

# %% [markdown]
# ## **Load**

# %%
# Salvando mensagem dos clientes devedores_conta em novo dataframe
devedores_conta = base.loc[base.Saldo_Conta < 0].copy()

novo_texto_coluna = []

for index, cliente in devedores_conta.iterrows():
    texto = f"Olá, {cliente['Nome']}! Agência {cliente['Agencia']} Conta {cliente['Conta']} Verificamos que há {cliente['Dias_Uso_Limite_Conta']} dias você está usando o limite do cheque especial da sua conta. Vamos contratar um empréstimo e reduzir a taxa de juros que você está pagando? Contate seu gerente de contas para obter opções mais vantajosas."
    novo_texto_coluna.append(texto)

devedores_conta.loc[:,'Mensagem_E-mail'] = novo_texto_coluna

# %%
# Salvando mensagem dos clientes saldo_positivo em novo dataframe
saldo_positivo = base.loc[base.Saldo_Conta >1000].copy()

novo_texto_coluna = []

for index, cliente in saldo_positivo.iterrows():
    texto = f"Olá, {cliente['Nome']}! Agência {cliente['Agencia']} Conta {cliente['Conta']} Verificamos que você possui R$ {cliente['Saldo_Conta']:.2f} disponível em sua conta corrente. Vamos investir e fazer o seu dinheiro render mais? Contate seu gerente de contas para obter opções mais vantajosas."
    novo_texto_coluna.append(texto)

saldo_positivo.loc[:,'Mensagem_E-mail'] = novo_texto_coluna

# %%
# Salvando mensagem dos clientes limite_cartao em novo dataframe
limite_cartao = base.loc[(base.Limite_Disponível_Cartão <1000) & 	(base.Dias_Uso_Limite_Conta == 0) & (base.Dias_Atraso_Cartao == 0)].copy()

novo_texto_coluna = []

for index, cliente in limite_cartao.iterrows():
    texto = f"Olá, {cliente['Nome']}! Agência {cliente['Agencia']} Conta {cliente['Conta']} Verificamos que você possui apenas R$ {cliente['Limite_Disponível_Cartão']:.2f} de limite disponível em seu cartão de crédito. Vamos aumentar seu limite para que você possa aproveitar ainda mais os benefícios do nosso cartão? Contate seu gerente de contas para obter opções mais vantajosas."
    novo_texto_coluna.append(texto)

limite_cartao.loc[:,'Mensagem_E-mail'] = novo_texto_coluna

# %%
# Salvando mensagem dos clientes devedores_cartao em novo dataframe
devedores_cartao = base.loc[base.Dias_Atraso_Cartao >0].copy()

novo_texto_coluna = []

for index, cliente in devedores_cartao.iterrows():
    texto = f"Olá, {cliente['Nome']}! Agência {cliente['Agencia']} Conta {cliente['Conta']} Verificamos que sua fatura do cartão de crédito está em atraso há {cliente['Dias_Atraso_Cartao']} dias.Vamos contratar um parcelamento de fatura e reduzir a taxa de juros que você está pagando? Contate seu gerente de contas para obter opções mais vantajosas."
    novo_texto_coluna.append(texto)

devedores_cartao.loc[:,'Mensagem_E-mail'] = novo_texto_coluna

# %%
# Fazendo o merge dos novos dataframes do a base inicial
bases = [devedores_conta, saldo_positivo, limite_cartao, devedores_cartao]
for i in bases:
  base = base.merge(i,how='left',on=['Nome', 'Agencia', 'Conta', 'e-mail', 'Saldo_Conta', 'Limite_Conta', 'Dias_Uso_Limite_Conta', 'Saldo_Cartao', 'Limite_Cartao', 'Limite_Disponível_Cartão', 'Dias_Atraso_Cartao'])
# Out:
# <ipython-input-112-554abafb7a76>:4: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Mensagem_E-mail_x'} in the result is deprecated and will raise a MergeError in a future version.
#   base = base.merge(i,how='left',on=['Nome', 'Agencia', 'Conta', 'e-mail', 'Saldo_Conta', 'Limite_Conta', 'Dias_Uso_Limite_Conta', 'Saldo_Cartao', 'Limite_Cartao', 'Limite_Disponível_Cartão', 'Dias_Atraso_Cartao'])

# %%
# Preenchendo valores nulos (NaN)
base.fillna('', inplace=True)

# %%
# Concatenando todas as colunas de mensagens em uma mesma coluna
base['Mensagem_E-mail'] = base.iloc[:,11] + base.iloc[:,12] + base.iloc[:,13] + base.iloc[:,14]

# %%
# Excluíndo colunas adicionais de mensagem
base =  base.drop(['Mensagem_E-mail_x', 'Mensagem_E-mail_y', 'Mensagem_E-mail_x', 'Mensagem_E-mail_y'],axis=1)

# %%
# Testando novamente a função criada no início para consultar mensagem a ser enviada para a cliente "Ana Santos"
get_cliente('Ana Santos')
# Out:
#           Nome  Agencia  Conta                  e-mail  Saldo_Conta  \
# 91  Ana Santos       18  61152  Ana_Santos@hotmail.com          298
#
#     Limite_Conta  Dias_Uso_Limite_Conta  Saldo_Cartao  Limite_Cartao  \
# 91          5800                      0           506           1000
#
#     Limite_Disponível_Cartão  Dias_Atraso_Cartao  \
# 91                       494                  31
#
#                                       Mensagem_E-mail
# 91  Olá, Ana Santos! Agência 18 Conta 61152 Verifi...

# %%
# Salvando em novo arquivo excel apenas os clientes para os quais será enviado e-mail
base_mensagem = base.loc[base['Mensagem_E-mail']!= '']
base_mensagem.to_excel('base_clientes_mensagem.xlsx')
